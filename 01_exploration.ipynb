# %% [markdown]
# ## Exploring the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv("data/atp_tennis.csv")

# %%
# Quick overview
display(df.head())
display(df.tail())
# Out:
#                            Tournament        Date         Series    Court  \
# 0  Australian Hardcourt Championships  2000-01-03  International  Outdoor
# 1  Australian Hardcourt Championships  2000-01-03  International  Outdoor
# 2  Australian Hardcourt Championships  2000-01-03  International  Outdoor
# 3  Australian Hardcourt Championships  2000-01-03  International  Outdoor
# 4  Australian Hardcourt Championships  2000-01-03  International  Outdoor
#
#   Surface      Round  Best of        Player_1       Player_2       Winner  \
# 0    Hard  1st Round        3      Dosedel S.    Ljubicic I.   Dosedel S.
# 1    Hard  1st Round        3      Clement A.     Enqvist T.   Enqvist T.
# 2    Hard  1st Round        3       Escude N.  Baccanello P.    Escude N.
# 3    Hard  1st Round        3  Knippschild J.     Federer R.   Federer R.
# 4    Hard  1st Round        3     Fromberg R.  Woodbridge T.  Fromberg R.
#
#    Rank_1  Rank_2  Pts_1  Pts_2  Odd_1  Odd_2        Score
# ...

# %%
# Match frequency by surface type
surface_counts = df['Surface'].value_counts()
print("Match frequency by surface:")
print(surface_counts)
# Out:
# Match frequency by surface:
# Surface
# Hard      36038
# Clay      21389
# Grass      7444
# Carpet     1632
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
colors = ['skyblue', 'orange', 'green', 'limegreen']
plt.bar(surface_counts.index, surface_counts.values, color=colors)
plt.xlabel("Surface Type")
plt.ylabel("Frequency")
plt.title("Number of Matches by Surface Type")
plt.show()

# %% [markdown]
# ## Analyzing top winners by surface

# %% [markdown]
# ### Hard Courts

# %%
hard_surface_filter = ((df['Tournament'] == 'Australian Open') | (df['Tournament'] == 'US Open')) & (df['Round'] == 'The Final')
df_final = df[hard_surface_filter]

hard_winners = df_final['Winner'].value_counts()

print("Top winners on Hard Courts:")
print(hard_winners)
# Out:
# Top winners on Hard Courts:
# Winner
# Djokovic N.       14
# Federer R.        11
# Nadal R.           5
# Agassi A.          3
# Sinner J.          3
# Safin M.           2
# Wawrinka S.        2
# Alcaraz C.         2
# Sampras P.         1
# Roddick A.         1
# Johansson T.       1
# Hewitt L.          1
# Del Potro J.M.     1
# Murray A.          1
# Cilic M.           1
# Thiem D.           1
# Medvedev D.        1
# Name: count, dtype: int64

# %%
hard_winners_name = hard_winners.index
hard_winners_freq = hard_winners.values

plt.barh(hard_winners_name, hard_winners_freq, color='skyblue')
plt.xlabel("Frequency")
plt.ylabel("Players")
plt.title("Top Winners on Hard Courts")
plt.show()

# %% [markdown]
# ### Clay Courts

# %%
clay_surface_filter = (df['Tournament'] == 'French Open') & (df['Round'] == 'The Final')
df_final = df[clay_surface_filter]

clay_winners = df_final['Winner'].value_counts()

print("Top winners on Clay Courts:")
print(clay_winners)
# Out:
# Top winners on Clay Courts:
# Winner
# Nadal R.        14
# Djokovic N.      3
# Kuerten G.       2
# Alcaraz C.       2
# Costa A.         1
# Ferrero J.C.     1
# Gaudio G.        1
# Federer R.       1
# Wawrinka S.      1
# Name: count, dtype: int64

# %%
clay_winners_name = clay_winners.index
clay_winners_freq = clay_winners.values

plt.barh(clay_winners_name, clay_winners_freq, color='orange')
plt.xlabel("Frequency")
plt.ylabel("Players")
plt.title("Top Winners on Clay Courts")
plt.show()

# %% [markdown]
# ### Grass Courts

# %%
grass_surface_filter = (df['Tournament'] == 'Wimbledon') & (df['Round'] == 'The Final')
df_final = df[grass_surface_filter]

grass_winners = df_final['Winner'].value_counts()

print("Top winners on Grass Courts:")
print(grass_winners)
# Out:
# Top winners on Grass Courts:
# Winner
# Federer R.       8
# Djokovic N.      7
# Nadal R.         2
# Murray A.        2
# Alcaraz C.       2
# Sampras P.       1
# Ivanisevic G.    1
# Hewitt L.        1
# Sinner J.        1
# Name: count, dtype: int64

# %%
grass_winners_name = grass_winners.index
grass_winners_freq = grass_winners.values

plt.barh(grass_winners_name, grass_winners_freq, color='green')
plt.xlabel("Frequency")
plt.ylabel("Players")
plt.title("Top Winners on Grass Courts")
plt.show()
